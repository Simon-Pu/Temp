# %% [markdown]
# <a href="https://colab.research.google.com/github/Simon-Pu/Temp/blob/master/pytorchviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install python-pydot python-pydot-ng graphviz
# !pip install graphviz
#!pip install hiddenlayer
# !pip install torchviz
import torch
import torchvision.models
#import hiddenlayer as hl
import torchvision.models as models
from torchviz import make_dot, make_dot_from_trace

# %%
# VGG16 with BatchNorm
mobilenet = models.mobilenet_v2()

x = torch.randn(1, 3, 224, 224).requires_grad_(True)
y = mobilenet(x)
make_dot(y, params=dict(list(mobilenet.named_parameters()) + [('x', x)]))

# Build HiddenLayer graph
# Jupyter Notebook renders it automatically
#hl.build_graph(model, torch.zeros([1, 3, 224, 224]))
