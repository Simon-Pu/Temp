# %% [markdown]
# # Load libraries

# %%
# !git clone https://github.com/koshian2/OctConv-TFKeras
# !mv OctConv-TFKeras/*.py ./
# Out:
# Cloning into 'OctConv-TFKeras'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 46 (delta 20), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (46/46), done.

# %% [markdown]
# # Train OctConv Wide ResNet
# * alpha = 0 -> normal wide res-net
# * alpha > 0 -> OctConv wide res-net
#
# It takes about 2 hour for training.

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, History
from tensorflow.contrib.tpu.python.tpu import keras_support
from models import *

from keras.datasets import cifar10
from keras.utils import to_categorical
import pickle, os, time

def lr_scheduler(epoch):
    x = 0.1
    if epoch >= 100: x /= 5.0
    if epoch >= 150: x /= 5.0
    if epoch >= 200: x /= 5.0
    return x

def train(alpha):
    (X_train, y_train), (X_test, y_test) = cifar10.load_data()
    train_gen = ImageDataGenerator(rescale=1.0/255, horizontal_flip=True, 
                                    width_shift_range=4.0/32.0, height_shift_range=4.0/32.0)
    test_gen = ImageDataGenerator(rescale=1.0/255)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    
    tf.logging.set_verbosity(tf.logging.FATAL)

    if alpha <= 0:
        model = create_normal_wide_resnet()
    else:
        model = create_octconv_wide_resnet(alpha)
    model.compile(SGD(0.1, momentum=0.9), "categorical_crossentropy", ["acc"])
    model.summary()

    # include the epoch in the file name. (uses `str.format`)
    checkpoint_path = "training/cp-{epoch:04d}.h5"
    checkpoint_dir = os.path.dirname(checkpoint_path)

    cp_callback = tf.keras.callbacks.ModelCheckpoint(
       checkpoint_path, verbose=1, save_weights_only=True,
       # Save weights, every 5-epochs.
       period=50)
    
    # convert to tpu model
    tpu_grpc_url = "grpc://"+os.environ["COLAB_TPU_ADDR"]
    tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
    strategy = keras_support.TPUDistributionStrategy(tpu_cluster_resolver)
    model = tf.contrib.tpu.keras_to_tpu_model(model, strategy=strategy)

    batch_size = 128
    scheduler = LearningRateScheduler(lr_scheduler)
    hist = History()
   
    start_time = time.time()
    model.fit_generator(train_gen.flow(X_train, y_train, batch_size, shuffle=True),
                        steps_per_epoch=X_train.shape[0]//batch_size,
                        validation_data=test_gen.flow(X_test, y_test, batch_size, shuffle=False),
                        validation_steps=X_test.shape[0]//batch_size,
                        callbacks=[scheduler, hist, cp_callback], max_queue_size=5, epochs=200)
    elapsed = time.time() - start_time
    
    model.save_weights(checkpoint_path, overwrite=True)    
    
    print(elapsed)

    history = hist.history
    history["elapsed"] = elapsed

    with open(f"octconv_alpha_{alpha}.pkl", "wb") as fp:
        pickle.dump(history, fp)

if __name__ == "__main__":
    train(0.25)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# average_pooling2d_30 (AveragePo (None, 16, 16, 3)    0           input_6[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_105 (OctConv2D)      [(None, 32, 32, 120) 8640        input_6[0][0]
#                                                                  average_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_215 (Bat (None, 32, 32, 120)  480         oct_conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_216 (Bat (None, 16, 16, 40)   160         oct_conv2d_105[0][1]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_215[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_216[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_106 (OctConv2D)      [(None, 32, 32, 120) 230400      activation_215[0][0]
#                                                                  activation_216[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_217 (Bat (None, 32, 32, 120)  480         oct_conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_218 (Bat (None, 16, 16, 40)   160         oct_conv2d_106[0][1]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_217[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_218[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_107 (OctConv2D)      [(None, 32, 32, 120) 230400      activation_217[0][0]
#                                                                  activation_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_219 (Bat (None, 32, 32, 120)  480         oct_conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_220 (Bat (None, 16, 16, 40)   160         oct_conv2d_107[0][1]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_219[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_220[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 32, 32, 120)  0           activation_219[0][0]
#                                                                  activation_215[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 16, 16, 40)   0           activation_220[0][0]
#                                                                  activation_216[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_108 (OctConv2D)      [(None, 32, 32, 120) 230400      add_90[0][0]
#                                                                  add_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_221 (Bat (None, 32, 32, 120)  480         oct_conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_222 (Bat (None, 16, 16, 40)   160         oct_conv2d_108[0][1]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_221[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_222[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_109 (OctConv2D)      [(None, 32, 32, 120) 230400      activation_221[0][0]
#                                                                  activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_223 (Bat (None, 32, 32, 120)  480         oct_conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_224 (Bat (None, 16, 16, 40)   160         oct_conv2d_109[0][1]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_223[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_224[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 32, 32, 120)  0           activation_223[0][0]
#                                                                  add_90[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 16, 16, 40)   0           activation_224[0][0]
#                                                                  add_91[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_110 (OctConv2D)      [(None, 32, 32, 120) 230400      add_92[0][0]
#                                                                  add_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_225 (Bat (None, 32, 32, 120)  480         oct_conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_226 (Bat (None, 16, 16, 40)   160         oct_conv2d_110[0][1]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_225[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_226[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_111 (OctConv2D)      [(None, 32, 32, 120) 230400      activation_225[0][0]
#                                                                  activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_227 (Bat (None, 32, 32, 120)  480         oct_conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_228 (Bat (None, 16, 16, 40)   160         oct_conv2d_111[0][1]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 32, 32, 120)  0           batch_normalization_v1_227[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 16, 16, 40)   0           batch_normalization_v1_228[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 32, 32, 120)  0           activation_227[0][0]
#                                                                  add_92[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 16, 16, 40)   0           activation_228[0][0]
#                                                                  add_93[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_31 (AveragePo (None, 16, 16, 120)  0           add_94[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_32 (AveragePo (None, 8, 8, 40)     0           add_95[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_112 (OctConv2D)      [(None, 16, 16, 240) 460800      average_pooling2d_31[0][0]
#                                                                  average_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_229 (Bat (None, 16, 16, 240)  960         oct_conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_230 (Bat (None, 8, 8, 80)     320         oct_conv2d_112[0][1]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_229[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_230[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_113 (OctConv2D)      [(None, 16, 16, 240) 921600      activation_229[0][0]
#                                                                  activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_231 (Bat (None, 16, 16, 240)  960         oct_conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_232 (Bat (None, 8, 8, 80)     320         oct_conv2d_113[0][1]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_231[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_232[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_114 (OctConv2D)      [(None, 16, 16, 240) 921600      activation_231[0][0]
#                                                                  activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_233 (Bat (None, 16, 16, 240)  960         oct_conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_234 (Bat (None, 8, 8, 80)     320         oct_conv2d_114[0][1]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_233[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_234[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 16, 16, 240)  0           activation_233[0][0]
#                                                                  activation_229[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 8, 8, 80)     0           activation_234[0][0]
#                                                                  activation_230[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_115 (OctConv2D)      [(None, 16, 16, 240) 921600      add_96[0][0]
#                                                                  add_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_235 (Bat (None, 16, 16, 240)  960         oct_conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_236 (Bat (None, 8, 8, 80)     320         oct_conv2d_115[0][1]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_235[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_236[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_116 (OctConv2D)      [(None, 16, 16, 240) 921600      activation_235[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_237 (Bat (None, 16, 16, 240)  960         oct_conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_238 (Bat (None, 8, 8, 80)     320         oct_conv2d_116[0][1]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_237[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_238[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 16, 16, 240)  0           activation_237[0][0]
#                                                                  add_96[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 8, 8, 80)     0           activation_238[0][0]
#                                                                  add_97[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_117 (OctConv2D)      [(None, 16, 16, 240) 921600      add_98[0][0]
#                                                                  add_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_239 (Bat (None, 16, 16, 240)  960         oct_conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_240 (Bat (None, 8, 8, 80)     320         oct_conv2d_117[0][1]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_239[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_240[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_118 (OctConv2D)      [(None, 16, 16, 240) 921600      activation_239[0][0]
#                                                                  activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_241 (Bat (None, 16, 16, 240)  960         oct_conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_242 (Bat (None, 8, 8, 80)     320         oct_conv2d_118[0][1]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 16, 16, 240)  0           batch_normalization_v1_241[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 8, 8, 80)     0           batch_normalization_v1_242[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 16, 16, 240)  0           activation_241[0][0]
#                                                                  add_98[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 8, 8, 80)     0           activation_242[0][0]
#                                                                  add_99[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_33 (AveragePo (None, 8, 8, 240)    0           add_100[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_34 (AveragePo (None, 4, 4, 80)     0           add_101[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_119 (OctConv2D)      [(None, 8, 8, 480),  1843200     average_pooling2d_33[0][0]
#                                                                  average_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_243 (Bat (None, 8, 8, 480)    1920        oct_conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_244 (Bat (None, 4, 4, 160)    640         oct_conv2d_119[0][1]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_243[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_244[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_120 (OctConv2D)      [(None, 8, 8, 480),  3686400     activation_243[0][0]
#                                                                  activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_245 (Bat (None, 8, 8, 480)    1920        oct_conv2d_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_246 (Bat (None, 4, 4, 160)    640         oct_conv2d_120[0][1]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_245[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_246[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_121 (OctConv2D)      [(None, 8, 8, 480),  3686400     activation_245[0][0]
#                                                                  activation_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_247 (Bat (None, 8, 8, 480)    1920        oct_conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_248 (Bat (None, 4, 4, 160)    640         oct_conv2d_121[0][1]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_247[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_248[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 8, 8, 480)    0           activation_247[0][0]
#                                                                  activation_243[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 4, 4, 160)    0           activation_248[0][0]
#                                                                  activation_244[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_122 (OctConv2D)      [(None, 8, 8, 480),  3686400     add_102[0][0]
#                                                                  add_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_249 (Bat (None, 8, 8, 480)    1920        oct_conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_250 (Bat (None, 4, 4, 160)    640         oct_conv2d_122[0][1]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_249[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_250[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_123 (OctConv2D)      [(None, 8, 8, 480),  3686400     activation_249[0][0]
#                                                                  activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_251 (Bat (None, 8, 8, 480)    1920        oct_conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_252 (Bat (None, 4, 4, 160)    640         oct_conv2d_123[0][1]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_251[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_252[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 8, 8, 480)    0           activation_251[0][0]
#                                                                  add_102[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 4, 4, 160)    0           activation_252[0][0]
#                                                                  add_103[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_124 (OctConv2D)      [(None, 8, 8, 480),  3686400     add_104[0][0]
#                                                                  add_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_253 (Bat (None, 8, 8, 480)    1920        oct_conv2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_254 (Bat (None, 4, 4, 160)    640         oct_conv2d_124[0][1]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_253[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_254[0][0]
# __________________________________________________________________________________________________
# oct_conv2d_125 (OctConv2D)      [(None, 8, 8, 480),  3686400     activation_253[0][0]
#                                                                  activation_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_255 (Bat (None, 8, 8, 480)    1920        oct_conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 8, 8, 480)    0           batch_normalization_v1_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_256 (Bat (None, 4, 4, 160)    640         oct_conv2d_125[0][1]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, 8, 8, 480)    0           activation_255[0][0]
#                                                                  add_104[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 4, 4, 160)    0           batch_normalization_v1_256[0][0]
# __________________________________________________________________________________________________
# average_pooling2d
200
# 79/79 [==============================] - 3s 41ms/step - loss: 0.3436 - acc: 0.9458
# 391/391 [==============================] - 34s 87ms/step - loss: 1.6821e-04 - acc: 1.0000 - val_loss: 0.3436 - val_acc: 0.9458
# Epoch 193/200
# 79/79 [==============================] - 3s 40ms/step - loss: 0.3438 - acc: 0.9454
# 391/391 [==============================] - 34s 87ms/step - loss: 3.9103e-04 - acc: 0.9999 - val_loss: 0.3438 - val_acc: 0.9454
# Epoch 194/200
# 79/79 [==============================] - 3s 40ms/step - loss: 0.3434 - acc: 0.9457
# 391/391 [==============================] - 34s 87ms/step - loss: 1.6951e-04 - acc: 0.9999 - val_loss: 0.3434 - val_acc: 0.9457
# Epoch 195/200
# 79/79 [==============================] - 3s 39ms/step - loss: 0.3428 - acc: 0.9458
# 391/391 [==============================] - 34s 87ms/step - loss: 1.9850e-04 - acc: 1.0000 - val_loss: 0.3428 - val_acc: 0.9458
# Epoch 196/200
# 79/79 [==============================] - 3s 41ms/step - loss: 0.3436 - acc: 0.9462
# 391/391 [==============================] - 34s 87ms/step - loss: 1.7252e-04 - acc: 1.0000 - val_loss: 0.3436 - val_acc: 0.9462
# Epoch 197/200
# 79/79 [==============================] - 3s 40ms/step - loss: 0.3432 - acc: 0.9462
# 391/391 [==============================] - 34s 87ms/step - loss: 1.7026e-04 - acc: 1.0000 - val_loss: 0.3432 - val_acc: 0.9462
# Epoch 198/200
# 79/79 [==============================] - 3s 40ms/step - loss: 0.3420 - acc: 0.9458
# 391/391 [==============================] - 34s 86ms/step - loss: 2.9501e-04 - acc: 0.9999 - val_loss: 0.3420 - val_acc: 0.9458
# Epoch 199/200
# 79/79 [==============================] - 3s 39ms/step - loss: 0.3430 - acc: 0.9451
# 391/391 [==============================] - 34s 87ms/step - loss: 2.3711e-04 - acc: 1.0000 - val_loss: 0.3430 - val_acc: 0.9451
# Epoch 200/200
# 79/79 [==============================] - 3s 39ms/step - loss: 0.3418 - acc: 0.9452
#
# Epoch 00200: saving model to training/cp-0200.h5
# 391/391 [==============================] - 329s 843ms/step - loss: 1.5699e-04 - acc: 1.0000 - val_loss: 0.3418 - val_acc: 0.9452
# 9510.728906393051

# %% [markdown]
# # Check Test Accuracy

# %%
with open("octconv_alpha_0.25.pkl", "rb") as fp:
    data = pickle.load(fp)
    print(f"Max test accuracy = {max(data['val_acc']):.04}")
# Out:
# Max test accuracy = 0.9467

# %%
# !ls training\
# Out:
# cp-0050.h5  cp-0100.h5	cp-0150.h5  cp-0200.h5	cp-{epoch:04d}.h5

# %%
import matplotlib.pyplot as plt
from models import *
import numpy as np
import time
from tqdm import tqdm

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
y_test = y_test[:1000]
X_test = X_test[:1000].reshape(-1, 32 * 32) / 255.0

# Restore the weights
model = create_octconv_wide_resnet(0.25)
model.load_weights('training/cp-0200.h5')

def eval_all():
    #loss, acc = model.evaluate(X_test, y_test)
    #print("Restored model, accuracy: {:5.2f}%".format(100*acc))
    #print("Restored model, accuracy: {:5.2f}%".format(100*acc))
    #X = np.random.rand(50000, 32, 32, 3).astype(np.float32)
    #for alpha in [0, 0.25, 0.5, 0.75]:
    #    if alpha == 0:
    #        model = create_normal_wide_resnet()
    #    else:
    #        model = create_octconv_wide_resnet(alpha)
    #results = []
    #for i in tqdm(range(20)):
    #st = time.time()
    Y_pred = model.predict(X_test, batch_size=128)
    plt.scatter(X_test, Y_test)
    plt.plot(X_test, Y_pred)
    plt.show()
    print('end')
    #results.append(time.time()-st)
    #results = np.array(results)
    #print("alpha = ", alpha)
    #print(f"Mean = {np.mean(results):.04}, Median = {np.median(results):.04}"+
    #          f", SD = {np.std(results):.04}")

if __name__ == "__main__":
    eval_all()
